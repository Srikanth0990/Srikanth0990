# %% [markdown]
# <a href="https://colab.research.google.com/github/Srikanth0990/Srikanth0990/blob/main/AI_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 20.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 4.1 MB/s eta 0:00:00
# ...

# %%
pip install ultralytics transformers

# %%
from ultralytics import YOLO
from transformers import pipeline
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
cv = YOLO("yolov8n.pt")

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-8ce72b6b-8b05-4bec-a4fe-6f95d75dccce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8ce72b6b-8b05-4bec-a4fe-6f95d75dccce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

os.listdir("/content")
# Out:
# ['.config', 'yolov8n.pt', 'images.jpeg', 'sample_data']

# %%
result = cv("/content/supermarket.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_802/1392706954.py in <cell line: 0>()
# ----> 1 result = cv("/content/supermarket.jpg")
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in __call__(self, source, stream, **kwargs)
#     176             ...     print(f"Detected {len(r)} objects in image")
#     177         """
# --> 178         return self.predict(source, stream, **kwargs)
#     179
#     180     @staticmethod
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     540         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     541             self.predictor.set_prompts(prompts)
# --> 542         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     543
# ...

# %%
result = cv("images.jpeg")
# Out:
# image 1/1 /content/images.jpeg: 640x640 9 persons, 448.4ms
# Speed: 18.4ms preprocess, 448.4ms inference, 59.1ms postprocess per image at shape (1, 3, 640, 640)

# %%
import os

print(os.listdir("/content"))
# Out:
# ['.config', 'yolov8n.pt', 'images.jpeg', 'sample_data']

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# Load the YOLO model
cv = YOLO("yolov8n.pt")

# Perform prediction
result = cv("/content/images.jpeg")

# Display the result
plt.imshow(result[0].plot())
plt.axis("off")
plt.show()
# Out:
# image 1/1 /content/images.jpeg: 640x640 9 persons, 248.5ms
# Speed: 4.0ms preprocess, 248.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
